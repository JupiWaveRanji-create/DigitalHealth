# %% [markdown]
# You can upload files from your local machine to the Colab runtime using the following code. This will open a file selection dialog. For folders, you will need to compress them (e.g., as a .zip file) and then upload the compressed file.

# %%
from google.colab import files

uploaded = files.upload()

for filename in uploaded.keys():
    print(f'Uploaded file "{filename}" with length {len(uploaded[filename])} bytes')
# Out:
#      <input type="file" id="files-cb0bafc6-ff6a-49ae-a1e5-1600deaa5971" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb0bafc6-ff6a-49ae-a1e5-1600deaa5971">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# List contents of the target directory
check_path = './extracted_files/Data/'

print(f"Contents of '{check_path}':")
if os.path.exists(check_path):
    for item in os.listdir(check_path):
        print(f"- {item}")
else:
    print(f"Error: Directory '{check_path}' does not exist.")
# Out:
# Contents of './extracted_files/':
# - Slide and Demo Notebooks
# - Data
# - Course Assignment Notebooks

# %%
import json

# notebook_content was previously read from the file './extracted_files/Course Assignment Notebooks/section04_assignments.ipynb'
# Let's parse it back into a Python dictionary
notebook_dict = json.loads(notebook_content)

# Now, let's extract the cells and prepare them for generation
generated_cells_data = []
for cell in notebook_dict['cells']:
    cell_type = cell['cell_type']
    source = ''.join(cell['source']) # Source is a list of strings, join them

    # Map 'code' type to 'python' for consistency with command schema
    if cell_type == 'code':
        generated_cells_data.append({'cell_type': 'python', 'code': source})
    elif cell_type == 'markdown':
        generated_cells_data.append({'cell_type': 'markdown', 'code': source})

# You would typically pass `generated_cells_data` to a function that generates cells.
# Since I need to output directly for the user, I'll generate each one individually
# in a sequence of generate_cells commands (if this were an actual execution environment)
# For this response, I'll represent it as a single block for clarity of intent,
# but internally I'd issue multiple generate_cells calls.

# For the purpose of generating the actual cells, I will iterate and create them.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-829340041.py in <cell line: 0>()
#       3 # notebook_content was previously read from the file './extracted_files/Course Assignment Notebooks/section04_assignments.ipynb'
#       4 # Let's parse it back into a Python dictionary
# ----> 5 notebook_dict = json.loads(notebook_content)
#       6
#       7 # Now, let's extract the cells and prepare them for generation
#
# NameError: name 'notebook_content' is not defined

# %% [markdown]
# # Assignment: Read a File into Python

# %% [markdown]
# Hi there,
#
# I hear you’re the new junior data scientist on the team. Welcome!
#
# Our polling partners just finished collecting survey data on the happiness levels in each country. I’ve attached the file.
#
# Can you load the data into Python and confirm the number of rows in the data and the range of the happiness scores? Then we can walk through next steps together.
#
# Thanks!\
# Anna
#
# *Attachment: happiness_survey_data.csv*

# %% [markdown]
# ### 1. Read in data from a csv file

# %%
import pandas as pd

file_path = './extracted_files/Data/happiness_survey_data.csv'
happiness_df = pd.read_csv(file_path)

print("First 5 rows of the DataFrame:")
print(happiness_df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2343061403.py in <cell line: 0>()
#       2
#       3 file_path = './extracted_files/Data/happiness_survey_data.csv'
# ----> 4 happiness_df = pd.read_csv(file_path)
#       5
#       6 print("First 5 rows of the DataFrame:")
#
# ...

# %%
import pandas as pd

file_path = './extracted_files/Data/happiness_survey_data.csv'
happiness_df = pd.read_csv(file_path)

print("First 5 rows of the DataFrame:")
print(happiness_df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2343061403.py in <cell line: 0>()
#       2
#       3 file_path = './extracted_files/Data/happiness_survey_data.csv'
# ----> 4 happiness_df = pd.read_csv(file_path)
#       5
#       6 print("First 5 rows of the DataFrame:")
#
# ...

# %% [markdown]
# ### 2. Store data in a DataFrame

# %%
df = happiness_df

# %%
df.head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0  Afghanistan  2008         3.723590        0.450662
# 1  Afghanistan  2009         4.401778        0.552308
# 2  Afghanistan  2010         4.758381        0.539075
# 3  Afghanistan  2011         3.831719        0.521104
# 4  Afghanistan  2012         3.782938        0.520637
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.718114                         50.500000
# 1                      0.678896                         50.799999
# 2                      0.600127                         51.099998
# 3                      0.495901                         51.400002
# 4                      0.530935                         51.700001

# %%
df.tail(3)
# Out:
#      country_name  year  happiness_score  social_support  \
# 2086     Zimbabwe  2019         2.693523        0.759162
# 2087     Zimbabwe  2020         3.159802        0.717243
# 2088     Zimbabwe  2021         3.154578        0.685151
#
#       freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 2086                      0.631908                         53.099998
# 2087                      0.643303                         53.575001
# 2088                      0.667636                         54.049999

# %% [markdown]
# ### 3. Quickly explore the data in the DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2089 entries, 0 to 2088
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   country_name                      2089 non-null   object
#  1   year                              2089 non-null   int64
#  2   happiness_score                   2089 non-null   float64
#  3   social_support                    2076 non-null   float64
#  4   freedom_to_make_life_choices      2057 non-null   float64
#  5   healthy_life_expectancy_at_birth  2031 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 98.1+ KB

# %%
# There is no direct URL to Colab's local runtime folders.
# You can interact with the folder programmatically or download files from it.
# For example, to list contents:
# import os
# for root, dirs, files in os.walk('./extracted_files/Data/'):
#     for name in files:
#         print(os.path.join(root, name))
#     for name in dirs:
#         print(os.path.join(root, name))

# %%
df.describe()
# Out:
#               year  happiness_score  social_support  \
# count  2089.000000      2089.000000     2076.000000
# mean   2013.727621         5.473747        0.811542
# std       4.455614         1.115567        0.118935
# min    2005.000000         2.178809        0.290184
# 25%    2010.000000         4.651972        0.747664
# 50%    2014.000000         5.405246        0.834770
# 75%    2017.000000         6.294282        0.904682
# max    2021.000000         8.018934        0.987343
#
#        freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# count                   2057.000000                       2031.000000
# mean                       0.745462                         63.180326
# std                        0.140751                          6.948546
# min                        0.257534                          6.720000
# 25%                        0.651689                         58.965000
# 50%                        0.767357                         64.980003
# ...

# %%
import zipfile
import os

# Replace 'your_uploaded_file.zip' with the name of your uploaded zip file
zip_file_name = 'Data+Science+in+Python+-+Data+Prep+&+EDA.zip'

# Specify the directory where you want to extract the files
extraction_path = './extracted_files'

# Create the extraction directory if it doesn't exist
os.makedirs(extraction_path, exist_ok=True)

try:
    with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
        zip_ref.extractall(extraction_path)
    print(f'Successfully extracted contents of {zip_file_name} to {extraction_path}')

    # List the contents of the extracted directory
    print('\nContents of extracted files:')
    for root, dirs, files in os.walk(extraction_path):
        for name in files:
            print(os.path.join(root, name))
        for name in dirs:
            print(os.path.join(root, name))

except FileNotFoundError:
    print(f"Error: The file '{zip_file_name}' was not found. Please check the filename.")
except zipfile.BadZipFile:
    print(f"Error: '{zip_file_name}' is not a valid zip file.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Successfully extracted contents of Data+Science+in+Python+-+Data+Prep+&+EDA.zip to ./extracted_files
#
# Contents of extracted files:
# ./extracted_files/Slide and Demo Notebooks
# ./extracted_files/Data
# ./extracted_files/Course Assignment Notebooks
# ./extracted_files/Slide and Demo Notebooks/section08_preparing_for_modeling_code.ipynb
# ./extracted_files/Slide and Demo Notebooks/section04_gathering_data_code.ipynb
# ./extracted_files/Slide and Demo Notebooks/section05_cleaning_data_code.ipynb
# ./extracted_files/Slide and Demo Notebooks/section06_exploratory_data_analysis_code.ipynb
# ./extracted_files/Slide and Demo Notebooks/.ipynb_checkpoints
# ./extracted_files/Slide and Demo Notebooks/.ipynb_checkpoints/section06_exploratory_data_analysis_code-checkpoint.ipynb
# ./extracted_files/Slide and Demo Notebooks/.ipynb_checkpoints/section04_gathering_data_code-checkpoint.ipynb
# ...

# %%
import pandas as pd
import os

file_path = './extracted_files/Data/Run Times.xlsx'

if os.path.exists(file_path):
    try:
        run_times_df = pd.read_excel(file_path)
        print("First 5 rows of 'Run Times.xlsx':")
        print(run_times_df.head())
    except Exception as e:
        print(f"An error occurred while reading the Excel file: {e}")
else:
    print(f"Error: The file '{file_path}' was not found after checking with os.path.exists().")
# Out:
# First 5 rows of 'Run Times.xlsx':
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain    Fee
# 0  False  $0.00
# 1   True  $0.00
# 2  False  $2.50
# 3  False  $0.00
# 4  False  $2.50

# %%
run_times = file_path

# %%
run_times
# Out:
# './extracted_files/Data/Run Times.xlsx'

# %%
run_times_df
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain    Fee
# 0  False  $0.00
# 1   True  $0.00
# 2  False  $2.50
# 3  False  $0.00
# 4  False  $2.50

# %%
run_times_df.dtypes
# Out:
# Name                    object
# Run Time               float64
# Warm Up Time            object
# Location                object
# Run Date        datetime64[ns]
# Race Date       datetime64[ns]
# Rain                      bool
# Fee                     object
# dtype: object

# %%
run_times.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4136279147.py in <cell line: 0>()
# ----> 1 run_times.info()
#
# AttributeError: 'str' object has no attribute 'info'

# %%
run_times_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          5 non-null      object
#  1   Run Time      5 non-null      float64
#  2   Warm Up Time  5 non-null      object
#  3   Location      5 non-null      object
#  4   Run Date      5 non-null      datetime64[ns]
#  5   Race Date     5 non-null      datetime64[ns]
#  6   Rain          5 non-null      bool
#  7   Fee           5 non-null      object
# dtypes: bool(1), datetime64[ns](2), float64(1), object(4)
# memory usage: 417.0+ bytes

# %%
run_times_df.head()
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain    Fee
# 0  False  $0.00
# 1   True  $0.00
# 2  False  $2.50
# 3  False  $0.00
# 4  False  $2.50

# %%
run_times_df.Fee = pd.to_numeric(run_times_df.Fee.str.replace('$', ''))

# %%
run_times_df.head()
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain    Fee
# 0  False  $0.00
# 1   True  $0.00
# 2  False  $2.50
# 3  False  $0.00
# 4  False  $2.50

# %%
run_times_df.dtypes
# Out:
# Name                    object
# Run Time               float64
# Warm Up Time            object
# Location                object
# Run Date        datetime64[ns]
# Race Date       datetime64[ns]
# Rain                      bool
# Fee                     object
# dtype: object

# %%
import pandas as pd
pd.to_numeric(run_times_df['Warm Up Time'], errors = 'coerce')
# Out:
# 0    3.5
# 1    3.5
# 2    NaN
# 3    2.2
# 4    2.0
# Name: Warm Up Time, dtype: float64

# %%
run_times_df['Warm Up Time']
# Out:
# 0      3.5
# 1      3.5
# 2    3 min
# 3      2.2
# 4        2
# Name: Warm Up Time, dtype: object

# %%
run_times_df['Warm Up Time'].str.replace('min', ' ')
# Out:
# 0    NaN
# 1    NaN
# 2    3
# 3    NaN
# 4    NaN
# Name: Warm Up Time, dtype: object

# %%
run_times_df['Warm Up Time'].astype('str').str.replace('min', ' ')
# Out:
# 0    3.5
# 1    3.5
# 2    3
# 3    2.2
# 4      2
# Name: Warm Up Time, dtype: object

# %%
run_times_df['Warm Up Time'] = pd.to_numeric(run_times_df['Warm Up Time'].astype('str').str.replace('min', ' '))

# %%
run_times_df.dtypes
# Out:
# Name                    object
# Run Time               float64
# Warm Up Time           float64
# Location                object
# Run Date        datetime64[ns]
# Race Date       datetime64[ns]
# Rain                      bool
# Fee                     object
# dtype: object

# %%
import pandas as pd
import os

file_path = './extracted_files/Data/Alarm Survey Data.xlsx'

if os.path.exists(file_path):
    try:
        alarm_survey_df = pd.read_excel(file_path)
        print("First 5 rows of 'Alarm Survey Data.xlsx':")
        print(alarm_survey_df.head())
    except Exception as e:
        print(f"An error occurred while reading the Excel file: {e}")
else:
    print(f"Error: The file '{file_path}' was not found.")
# Out:
# First 5 rows of 'Alarm Survey Data.xlsx':
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes alarm_rating
# 0                  1      5 stars
# 1                  3      3 stars
# 2                  1      1 stars
# 3                  1      4 stars
# 4                  4      3 stars

# %%
print("\n--- Info for alarm_survey_df ---")
alarm_survey_df.info()
# Out:
# --- Info for alarm_survey_df ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6082 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 351.9+ KB

# %%
print("\n--- Description for alarm_survey_df ---")
alarm_survey_df.describe()
# Out:
# --- Description for alarm_survey_df ---
#          survey_id          age  number_of_children  sleep_quality  \
# count  6433.000000  6433.000000         6433.000000    6082.000000
# mean   3216.302192    29.069175            1.395616       4.232654
# std    1856.007409     7.472048            1.432192       0.842448
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1609.000000    23.000000            0.000000       4.000000
# 50%    3217.000000    28.000000            1.000000       4.000000
# 75%    4825.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes
# count        6433.000000
# mean            1.145811
# std             1.599481
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             2.000000
# max            19.000000

# %%
alarm_survey_df.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating            int64
# dtype: object

# %%
alarm_survey_df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes alarm_rating
# 0                  1      5 stars
# 1                  3      3 stars
# 2                  1      1 stars
# 3                  1      4 stars
# 4                  4      3 stars

# %%
alarm_survey_df['alarm_rating'] = pd.to_numeric(alarm_survey_df['alarm_rating'].astype('str').str.replace(' stars', ''))

# %%
alarm_survey_df.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating            int64
# dtype: object

# %% [markdown]
# # Assignments: Cleaning Data

# %% [markdown]
# ## 1. Data in Python Request

# %% [markdown]
# * Read in data from the Excel spreadsheet (Alarm Survey Data.xlsx) and put into a Pandas DataFrame
# * Check the data type of each column
# * Convert object columns into numeric or datetime columns, as needed

# %%
import pandas as pd

# %%
df = pd.read_excel('./extracted_files/Data/Alarm Survey Data.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-644349691.py in <cell line: 0>()
# ----> 1 df = pd.read_excel('./extracted_files/Data/Alarm Survey Data.xlsx')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes alarm_rating
# 0                  1      5 stars
# 1                  3      3 stars
# 2                  1      1 stars
# 3                  1      4 stars
# 4                  4      3 stars

# %% [markdown]
# ## 2. Missing Data Check

# %% [markdown]
# * Find any missing data
# * Deal with the missing data

# %%
print("Missing values in alarm_survey_df:")
print(alarm_survey_df.isnull().sum())
# Out:
# Missing values in alarm_survey_df:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3381553232.py in <cell line: 0>()
#       1 print("Missing values in alarm_survey_df:")
# ----> 2 print(alarm_survey_df.isnull().sum())
#
# NameError: name 'alarm_survey_df' is not defined

# %%
df['alarm_rating']=pd.to_numeric(df['alarm_rating'].astype('str').str.replace(' stars', ''))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'alarm_rating'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4259451543.py in <cell line: 0>()
# ...

# %%
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes alarm_rating
# 0                  1      5 stars
# 1                  3      3 stars
# 2                  1      1 stars
# 3                  1      4 stars
# 4                  4      3 stars

# %%
df.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating            int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6082 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 351.9+ KB

# %%
df[df.isna().any(axis=1)]
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 10           11   28                 2.0  light_activity            NaN
# 18           19   38                 2.0  lightly active            NaN
# 23           24   24                 2.0     very active            NaN
# 26           27   25                 2.0  lightly active            NaN
# 28           29   29                 2.0  lightly active            NaN
# ...         ...  ...                 ...             ...            ...
# 6310       6311   30                 2.0     very active            NaN
# 6319       6320   44                 2.0  lightly active            NaN
# 6375       6309   32                 3.0           light            NaN
# 6377       6311   30                 2.0     very active            NaN
# 6386       6320   44                 2.0  lightly active            NaN
#
#       number_of_snoozes alarm_rating
# 10                    3      4 stars
# ...

# %%
df.sleep_quality.value_counts(dropna=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1947196287.py in <cell line: 0>()
# ----> 1 df.sleep_quality.value_counts(dropna=False)
#
# NameError: name 'df' is not defined

# %%
df.sleep_quality.fillna(2).value_counts(dropna=False)
# Out:
# sleep_quality
# 5.0    2721
# 4.0    2261
# 3.0     997
# 2.0     351
# 1.0     103
# Name: count, dtype: int64

# %%
df.sleep_quality.fillna(2, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-178404303.py in <cell line: 0>()
# ----> 1 df.sleep_quality.fillna(2, inplace=True)
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   survey_id           6433 non-null   int64
#  1   age                 6433 non-null   int64
#  2   number_of_children  6433 non-null   float64
#  3   activity_level      6433 non-null   object
#  4   sleep_quality       6433 non-null   float64
#  5   number_of_snoozes   6433 non-null   int64
#  6   alarm_rating        6433 non-null   object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 351.9+ KB

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-964094849.py in <cell line: 0>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 3. Inconsistent Text & Typos Check

# %% [markdown]
# * Find any inconsistent text and typos
# * Deal with the inconsistent text and typos

# %% [markdown]
# # Assignments: Cleaning Data

# %% [markdown]
# ## 1. Data in Python Request

# %% [markdown]
# * Read in data from the Excel spreadsheet (Alarm Survey Data.xlsx) and put into a Pandas DataFrame
# * Check the data type of each column
# * Convert object columns into numeric or datetime columns, as needed

# %% [markdown]
# ## 2. Missing Data Check

# %% [markdown]
# * Find any missing data
# * Deal with the missing data

# %%
import pandas as pd
df = pd.read_excel('./extracted_files/Data/Student Grades.xlsx')

# %%
df.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df.head()
# Out:
#     Student                      Class      Year      Grade
# 7     Jacob           Freshman Seminar  Freshman  88.000000
# 8   William           Freshman Seminar  Freshman  89.000000
# 9     Ethan           Freshman Seminar  Freshman  86.000000
# 62   Landon  Exploratory Data Analysis    Junior  87.666667
# 84    Gavin                        EDA    Senior  87.666667

# %%
df

# %%
df.tail()
# Out:
#     Student Class    Year  Grade
# 81      NaN   NaN     NaN    NaN
# 82  Bennett   NaN     NaN    NaN
# 83      NaN   EDA  Junior   84.0
# 84    Gavin   EDA  Senior    NaN
# 85   Calvin   NaN     NaN  100.0

# %%
import numpy as np
np.nan
# Out:
# nan

# %%
pd.NA

# %%
df.isna()
# Out:
#     Student  Class   Year  Grade
# 0     False  False  False  False
# 1     False  False  False  False
# 2     False  False  False  False
# 3     False  False  False  False
# 4     False  False  False  False
# ..      ...    ...    ...    ...
# 81     True   True   True   True
# 82    False   True   True   True
# 83     True  False  False  False
# 84    False  False  False   True
# 85    False   True   True  False
#
# [86 rows x 4 columns]

# %%
df.tail()
# Out:
#     Student Class    Year  Grade
# 81      NaN   NaN     NaN    NaN
# 82  Bennett   NaN     NaN    NaN
# 83      NaN   EDA  Junior   84.0
# 84    Gavin   EDA  Senior    NaN
# 85   Calvin   NaN     NaN  100.0

# %%
np.nan
# Out:
# nan

# %%
import numpy as np

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  84 non-null     object
#  1   Class    83 non-null     object
#  2   Year     80 non-null     object
#  3   Grade    82 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 2.8+ KB

# %%
df.Year.value_counts(dropna=False)
# Out:
# Year
# Freshman     35
# Sophomore    24
# Junior       20
# NaN           6
# Senior        1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Student    2
# Class      3
# Year       6
# Grade      4
# dtype: int64

# %%
df.isna().any(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 81     True
# 82     True
# 83     True
# 84     True
# 85     True
# Length: 86, dtype: bool

# %%
df[df.isna().any(axis=1)]
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 81      NaN                        NaN     NaN    NaN
# 82  Bennett                        NaN     NaN    NaN
# 83      NaN                        EDA  Junior   84.0
# 84    Gavin                        EDA  Senior    NaN
# 85   Calvin                        NaN     NaN  100.0

# %%
df[df.isna().any(axis=1)].dropna(subset=['Student', 'Class'])
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 84    Gavin                        EDA  Senior    NaN

# %%
df[df.isna().any(axis=1)]
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 84    Gavin                        EDA  Senior    NaN

# %%
df.Grade
# Out:
# 7     88.0
# 8     89.0
# 9     86.0
# 62     NaN
# 84     NaN
# Name: Grade, dtype: float64

# %%
df[df.Grade.isna()]
# Out:
#    Student                      Class    Year  Grade
# 62  Landon  Exploratory Data Analysis  Junior    NaN
# 84   Gavin                        EDA  Senior    NaN

# %%
df.Grade.fillna(df.Grade.mean())
# Out:
# 7     88.000000
# 8     89.000000
# 9     86.000000
# 62    87.666667
# 84    87.666667
# Name: Grade, dtype: float64

# %%
df.Grade
# Out:
# 7     88.0
# 8     89.0
# 9     86.0
# 62     NaN
# 84     NaN
# Name: Grade, dtype: float64

# %%
df.Grade.mean()
# Out:
# np.float64(87.66666666666667)

# %%
df[df.isna().any(axis=1)]
# Out:
#     Student                      Class    Year  Grade
# 7     Jacob           Freshman Seminar     NaN   88.0
# 8   William           Freshman Seminar     NaN   89.0
# 9     Ethan           Freshman Seminar     NaN   86.0
# 62   Landon  Exploratory Data Analysis  Junior    NaN
# 84    Gavin                        EDA  Senior    NaN

# %%
df.Grade
# Out:
# 7     88.0
# 8     89.0
# 9     86.0
# 62     NaN
# 84     NaN
# Name: Grade, dtype: float64

# %%
df[df.Grade.isna()]
# Out:
#    Student                      Class    Year  Grade
# 62  Landon  Exploratory Data Analysis  Junior    NaN
# 84   Gavin                        EDA  Senior    NaN

# %%
df.Grade.mean()
# Out:
# np.float64(87.66666666666667)

# %%
df.Grade.fillna(df.Grade.mean(), inplace=True)

# %%
df.Grade
# Out:
# 7     88.000000
# 8     89.000000
# 9     86.000000
# 62    87.666667
# 84    87.666667
# Name: Grade, dtype: float64

# %%
df[df.isna().any(axis=1)]
# Out:
#    Student             Class Year  Grade
# 7    Jacob  Freshman Seminar  NaN   88.0
# 8  William  Freshman Seminar  NaN   89.0
# 9    Ethan  Freshman Seminar  NaN   86.0

# %%
df[df.Class == 'Freshman Seminar']
# Out:
#    Student             Class Year  Grade
# 7    Jacob  Freshman Seminar  NaN   88.0
# 8  William  Freshman Seminar  NaN   89.0
# 9    Ethan  Freshman Seminar  NaN   86.0

# %%
df.loc[7, 'Year']='Freshman'

# %%
df[df.Class == 'Freshman Seminar']
# Out:
#    Student             Class      Year  Grade
# 7    Jacob  Freshman Seminar  Freshman   88.0
# 8  William  Freshman Seminar  Freshman   89.0
# 9    Ethan  Freshman Seminar  Freshman   86.0

# %%
import numpy as np
df.Year = np.where(df.Year.isna(),'Freshman',df.Year)
df
# Out:
#     Student                      Class      Year      Grade
# 7     Jacob           Freshman Seminar  Freshman  88.000000
# 8   William           Freshman Seminar  Freshman  89.000000
# 9     Ethan           Freshman Seminar  Freshman  86.000000
# 62   Landon  Exploratory Data Analysis    Junior  87.666667
# 84    Gavin                        EDA    Senior  87.666667

# %%
df.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df.Class.value_counts()
# Out:
# Class
# Intro to Python              25
# Intro to SQL                 20
# EDA                          13
# Freshman Seminar             12
# Exploratory Data Analysis    12
# Python                        1
# Name: count, dtype: int64

# %%
df[df.Class.isin(['Exploratory Data Analysis', 'EDA'])]
# Out:
#       Student                      Class       Year  Grade
# 58     Evelyn  Exploratory Data Analysis  Sophomore   89.0
# 59       Jack  Exploratory Data Analysis  Sophomore   84.0
# 60       Ella  Exploratory Data Analysis  Sophomore  200.0
# 61      Chloe  Exploratory Data Analysis  Sophomore   87.0
# 62     Landon  Exploratory Data Analysis     Junior    NaN
# 63  Christian  Exploratory Data Analysis     Junior   77.0
# 64     Jordan  Exploratory Data Analysis     Junior   83.0
# 65   Jonathan  Exploratory Data Analysis     Junior   82.0
# 66       Levi  Exploratory Data Analysis     Junior   91.0
# 67   Victoria  Exploratory Data Analysis     Junior   90.0
# 68     Aubrey  Exploratory Data Analysis     Junior   83.0
# 69      Jaxon  Exploratory Data Analysis     Junior   64.0
# 70     Julian                        EDA     Junior   95.0
# 71      Grace                        EDA     Junior   77.0
# 72     Isaiah                        EDA     Junior   88.0
# ...

# %%
df[df.Class.isin(['Intro to Python', 'Python'])]
# Out:
#       Student            Class      Year  Grade
# 12  Alexander  Intro to Python  Freshman   85.0
# 13      Logan  Intro to Python  Freshman   85.0
# 14      James  Intro to Python  Freshman   82.0
# 15     Daniel  Intro to Python  Freshman   85.0
# 16     Elijah  Intro to Python  Freshman   85.0
# 17   Benjamin  Intro to Python  Freshman   81.0
# 18        Mia  Intro to Python  Freshman   80.0
# 19        Mia           Python  Freshman   80.0
# 20     Jayden  Intro to Python  Freshman   82.0
# 21      Aiden  Intro to Python  Freshman   86.0
# 22    Matthew  Intro to Python  Freshman   87.0
# 23      Emily  Intro to Python  Freshman   78.0
# 24    Jackson  Intro to Python  Freshman   88.0
# 25      Lucas  Intro to Python  Freshman   77.0
# 26      David  Intro to Python  Freshman   74.0
# 27     Joseph  Intro to Python  Freshman   93.0
# 28    Abigail  Intro to Python  Freshman   89.0
# 29      Avery  Intro to Python  Freshman   79.0
# 30    Anthony  Intro to Python  Freshman   84.0
# ...

# %%
import numpy as np
df.Class = np.where(df.Class =='EDA','Exploratory Data Analysis', df.Class)
df.Class
# Out:
# 0              Freshman Seminar
# 1              Freshman Seminar
# 2              Freshman Seminar
# 3              Freshman Seminar
# 4              Freshman Seminar
#                 ...
# 81                          NaN
# 82                          NaN
# 83    Exploratory Data Analysis
# 84    Exploratory Data Analysis
# 85                          NaN
# Name: Class, Length: 86, dtype: object

# %%
df.Class.value_counts()
# Out:
# Class
# Intro to Python              26
# Exploratory Data Analysis    25
# Intro to SQL                 20
# Freshman Seminar             12
# Name: count, dtype: int64

# %%
df.Class = np.where(df.Class =='Python','Intro to Python', df.Class)
df.Class
# Out:
# 0              Freshman Seminar
# 1              Freshman Seminar
# 2              Freshman Seminar
# 3              Freshman Seminar
# 4              Freshman Seminar
#                 ...
# 81                          NaN
# 82                          NaN
# 83    Exploratory Data Analysis
# 84    Exploratory Data Analysis
# 85                          NaN
# Name: Class, Length: 86, dtype: object

# %%
df.Grade = np.where(df.Grade > 100, 100, df.Grade)
df.Grade
# Out:
# 0      86.0
# 1      86.0
# 2      86.0
# 3      87.0
# 4      90.0
#       ...
# 81      NaN
# 82      NaN
# 83     84.0
# 84      NaN
# 85    100.0
# Name: Grade, Length: 86, dtype: float64

# %%
df.Grade.describe()
# Out:
# count     82.000000
# mean      84.487805
# std        8.991414
# min       45.000000
# 25%       81.000000
# 50%       85.000000
# 75%       90.000000
# max      100.000000
# Name: Grade, dtype: float64

# %%
import pandas as pd
df_grades = pd.read_excel('./extracted_files/Data/Student Grades.xlsx')

# %%
df_grades.Class.value_counts()
# Out:
# Class
# Intro to Python              26
# Intro to SQL                 20
# Freshman Seminar             12
# Exploratory Data Analysis    12
# Name: count, dtype: int64

# %%
Class_mappings ={'Intro to Python' : 'Intro to Python',
'Intro to SQL': 'Intro to SQL',
                 'EDA': 'Eploratory Data Analysis',
                 'Freshman Seminar': 'Freshman Seminar',
                 'Exploratory Data Analysis': 'Exploratory Data Analysis',
                 'Python':'Intro to Python'}

# %%
df_grades.Class = df_grades.Class.map(Class_mappings)

# %%
df_grades.head()
# Out:
#   Student             Class      Year  Grade
# 0    Emma  Freshman Seminar  Freshman   86.0
# 1  Olivia  Freshman Seminar  Freshman   86.0
# 2    Noah  Freshman Seminar  Freshman   86.0
# 3  Sophia  Freshman Seminar  Freshman   87.0
# 4    Liam  Freshman Seminar  Freshman   90.0

# %%
df_grades['Class_clean'] = df_grades.Class.map(Class_mappings)
df_grades
# Out:
#     Student             Class      Year  Grade       Class_clean
# 0      Emma  Freshman Seminar  Freshman   86.0  Freshman Seminar
# 1    Olivia  Freshman Seminar  Freshman   86.0  Freshman Seminar
# 2      Noah  Freshman Seminar  Freshman   86.0  Freshman Seminar
# 3    Sophia  Freshman Seminar  Freshman   87.0  Freshman Seminar
# 4      Liam  Freshman Seminar  Freshman   90.0  Freshman Seminar
# ..      ...               ...       ...    ...               ...
# 81      NaN               NaN       NaN    NaN               NaN
# 82  Bennett               NaN       NaN    NaN               NaN
# 83      NaN               NaN    Junior   84.0               NaN
# 84    Gavin               NaN    Senior    NaN               NaN
# 85   Calvin               NaN       NaN  100.0               NaN
#
# [86 rows x 5 columns]

# %%
import pandas as pd
import os

file_path = './extracted_files/Data/Run Times.xlsx'

run_times = pd.read_excel(file_path)

run_times.head()
# Out:
#      Name  Run Time Warm Up Time   Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   “school” 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5     School 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min  “the gym” 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   “school” 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      “gym” 2023-05-10 16:30:00 2023-06-15
#
#     Rain    Fee
# 0  False  $0.00
# 1   True  $0.00
# 2  False  $2.50
# 3  False  $0.00
# 4  False  $2.50

# %%
run_times['Location'] = run_times.Location.str.strip('“”').str.lower().str.replace('the ', '')

# %%
run_times
# Out:
#      Name  Run Time Warm Up Time Location            Run Date  Race Date  \
# 0  Alexis    9.2343          3.5   school 2023-04-15 12:00:00 2023-06-01
# 1  Alexis   10.3842          3.5   school 2023-04-22 12:30:00 2023-06-01
# 2  Alexis    8.1209        3 min      gym 2023-05-10 15:00:00 2023-06-01
# 3   David    7.2123          2.2   school 2023-05-01 15:15:00 2023-06-15
# 4   David    6.8342            2      gym 2023-05-10 16:30:00 2023-06-15
#
#     Rain    Fee
# 0  False  $0.00
# 1   True  $0.00
# 2  False  $2.50
# 3  False  $0.00
# 4  False  $2.50

# %% [markdown]
# ## 3. Inconsistent Text & Typos Check

# %% [markdown]
# * Find any inconsistent text and typos
# * Deal with the inconsistent text and typos

# %%
df = pd.read_excel('./extracted_files/Data/Alarm Survey Data.xlsx')
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes alarm_rating
# 0                  1      5 stars
# 1                  3      3 stars
# 2                  1      1 stars
# 3                  1      4 stars
# 4                  4      3 stars

# %%
df.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6433.000000  6433.000000         6433.000000    6082.000000
# mean   3216.302192    29.069175            1.395616       4.232654
# std    1856.007409     7.472048            1.432192       0.842448
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1609.000000    23.000000            0.000000       4.000000
# 50%    3217.000000    28.000000            1.000000       4.000000
# 75%    4825.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes
# count        6433.000000
# mean            1.145811
# std             1.599481
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             2.000000
# max            19.000000

# %%
df.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating           object
# dtype: object

# %%
df['alarm_rating'] = df['alarm_rating'].str.extract(r'(\d+)')
df['alarm_rating'] = df['alarm_rating'].astype(int)
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes  alarm_rating
# 0                  1             5
# 1                  3             3
# 2                  1             1
# 3                  1             4
# 4                  4             3

# %%
df['alarm_rating'] = (df['alarm_rating'].astype(str).str.extract(r'(\d+)')[0])
df.head()
# Out:
#    survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0          1   34                 3.0          active            3.0
# 1          2   31                 3.0           light            3.0
# 2          3   18                 0.0  light_activity            4.0
# 3          4   42                 4.0          active            4.0
# 4          5   30                 1.0  light_activity            1.0
#
#    number_of_snoozes alarm_rating
# 0                  1            5
# 1                  3            3
# 2                  1            1
# 3                  1            4
# 4                  4            3

# %%
df['alarm_rating'] = pd.to_numeric(df['alarm_rating'], errors='coerce').astype('Int64')

# %%
df.dtypes
# Out:
# survey_id               int64
# age                     int64
# number_of_children    float64
# activity_level         object
# sleep_quality         float64
# number_of_snoozes       int64
# alarm_rating            Int64
# dtype: object

# %%
df.describe()
# Out:
#          survey_id          age  number_of_children  sleep_quality  \
# count  6433.000000  6433.000000         6433.000000    6082.000000
# mean   3216.302192    29.069175            1.395616       4.232654
# std    1856.007409     7.472048            1.432192       0.842448
# min       1.000000    13.000000            0.000000       1.000000
# 25%    1609.000000    23.000000            0.000000       4.000000
# 50%    3217.000000    28.000000            1.000000       4.000000
# 75%    4825.000000    34.000000            2.000000       5.000000
# max    6366.000000    47.000000            5.500000       5.000000
#
#        number_of_snoozes  alarm_rating
# count        6433.000000        6433.0
# mean            1.145811      2.955075
# std             1.599481      1.101363
# min             0.000000           1.0
# 25%             0.000000           2.0
# 50%             0.000000           3.0
# 75%             2.000000           4.0
# max            19.000000           5.0

# %%
df.number_of_children.value_counts()
# Out:
# number_of_children
# 0.0    2440
# 2.0    1498
# 1.0    1172
# 3.0     788
# 4.0     331
# 5.5     204
# Name: count, dtype: int64

# %%
import numpy as np
df.activity_level = np.where(df.activity_level.isin(['light_activity', 'light']),'lightly active', df.activity_level)

# %%
df.activity_level.value_counts()
# Out:
# activity_level
# lightly active    3314
# active            2450
# very active        669
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Duplicate Data Check

# %% [markdown]
# * Find any duplicate data
# * Deal with the duplicate data

# %%
df
# Out:
#       survey_id  age  number_of_children  activity_level  sleep_quality  \
# 0             1   34                 3.0          active            3.0
# 1             2   31                 3.0  lightly active            3.0
# 2             3   18                 0.0  lightly active            4.0
# 3             4   42                 4.0          active            4.0
# 4             5   30                 1.0  lightly active            1.0
# ...         ...  ...                 ...             ...            ...
# 6428       6362   27                 2.0          active            5.0
# 6429       6363   31                 1.0  lightly active            4.0
# 6430       6364   26                 0.0  lightly active            5.0
# 6431       6365   27                 1.0          active            5.0
# 6432       6366   18                 0.0  lightly active            4.0
#
#       number_of_snoozes  alarm_rating
# 0                     1             5
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428     True
# 6429     True
# 6430     True
# 6431     True
# 6432     True
# Length: 6433, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(67)

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [survey_id, age, number_of_children, activity_level, sleep_quality, number_of_snoozes, alarm_rating]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.iloc[40:45, :]
# Out:
#     survey_id  age  number_of_children  activity_level  sleep_quality  \
# 40         41   23                 0.0  lightly active            4.0
# 41         42   23                 0.0  lightly active            4.0
# 42         43   38                 3.0  lightly active            4.0
# 43         44   18                 0.0  lightly active            4.0
# 44         45   19                 0.0  lightly active            4.0
#
#     number_of_snoozes  alarm_rating
# 40                  1             4
# 41                  3             3
# 42                  1             4
# 43                  5             1
# 44                  5             3

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6361    False
# 6362    False
# 6363    False
# 6364    False
# 6365    False
# Length: 6366, dtype: bool

# %% [markdown]
# ## 5. Outliers Check

# %% [markdown]
# * Find any outliers
# * Deal with the outliers

# %% [markdown]
# ## 6. Data Issues Check

# %% [markdown]
# * Quickly explore the updated DataFrame. How do things look now after handling the data issues compared to the original DataFrame?

# %% [markdown]
# ## 7. Create Columns From Numeric Data

# %% [markdown]
# * Read data into Python
# * Check the data type of each column
# * Create a numeric column using arithmetic
# * Create a numeric column using conditional logic

# %%
# Create a “Total Spend” column that includes both the pen cost and shipping cost for each sale
# Create a “Free Shipping” column that says yes if the sale included free shipping, and no otherwise

# %% [markdown]
# ## 8. Create Columns From DateTime Data

# %% [markdown]
# * Calculate the difference between two datetime columns and save it as a new column
# * Take the average of a column

# %%
# Calculate the number of days between the purchase and delivery date for each sale
# Save it as a new column called “Delivery Time”
# What were the average days from purchase to delivery?

# %% [markdown]
# ## 9. Create Columns From Text Data

# %% [markdown]
# * Split one column into multiple columns
# * Create a Boolean column (True / False) to show whether a text field contains particular words

# %%
# Split the reviews on the “|” character to create two new columns: “User Name” and “Review Text”
# Create a “Leak or Spill” column that flags the reviews that mention either “leak” or “spill”

# %% [markdown]
# ## 4. Duplicate Data Check

# %% [markdown]
# * Find any duplicate data
# * Deal with the duplicate data

# %% [markdown]
# ## 5. Outliers Check

# %% [markdown]
# * Find any outliers
# * Deal with the outliers

# %% [markdown]
# ## 6. Data Issues Check

# %% [markdown]
# * Quickly explore the updated DataFrame. How do things look now after handling the data issues compared to the original DataFrame?

# %% [markdown]
# ## 7. Create Columns From Numeric Data

# %% [markdown]
# * Read data into Python
# * Check the data type of each column
# * Create a numeric column using arithmetic
# * Create a numeric column using conditional logic

# %%
# Create a “Total Spend” column that includes both the pen cost and shipping cost for each sale
# Create a “Free Shipping” column that says yes if the sale included free shipping, and no otherwise

# %% [markdown]
# ## 8. Create Columns From DateTime Data

# %% [markdown]
# * Calculate the difference between two datetime columns and save it as a new column
# * Take the average of a column

# %%
# Calculate the number of days between the purchase and delivery date for each sale
# Save it as a new column called “Delivery Time”
# What were the average days from purchase to delivery?

# %% [markdown]
# ## 9. Create Columns From Text Data

# %% [markdown]
# * Split one column into multiple columns
# * Create a Boolean column (True / False) to show whether a text field contains particular words

# %%
# Split the reviews on the “|” character to create two new columns: “User Name” and “Review Text”
# Create a “Leak or Spill” column that flags the reviews that mention either “leak” or “spill”

# %%
import json

# notebook_content_05 was previously read from the file './extracted_files/Course Assignment Notebooks/section05_assignments.ipynb'
# Let's parse it back into a Python dictionary
notebook_dict_05 = json.loads(notebook_content_05)

# Now, let's extract the cells and prepare them for generation
generated_cells_data_05 = []
for cell in notebook_dict_05['cells']:
    cell_type = cell['cell_type']
    source = ''.join(cell['source']) # Source is a list of strings, join them

    # Map 'code' type to 'python' for consistency with command schema
    if cell_type == 'code':
        generated_cells_data_05.append({'cell_type': 'python', 'code': source})
    elif cell_type == 'markdown':
        generated_cells_data_05.append({'cell_type': 'markdown', 'code': source})

# For the purpose of generating the actual cells, I will iterate and create them.

# %%
print(f"Number of rows in happiness_df: {len(happiness_df)}")
print(f"Range of happiness scores: {happiness_df['happiness_score'].min()} to {happiness_df['happiness_score'].max()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1350528708.py in <cell line: 0>()
# ----> 1 print(f"Number of rows in happiness_df: {len(happiness_df)}")
#       2 print(f"Range of happiness scores: {happiness_df['happiness_score'].min()} to {happiness_df['happiness_score'].max()}")
#
# NameError: name 'happiness_df' is not defined

# %%
file_path = './extracted_files/Course Assignment Notebooks/section05_assignments.ipynb'

try:
    with open(file_path, 'r') as f:
        notebook_content_05 = f.read()
    print(notebook_content_05)
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Assignments: Cleaning Data"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "## 1. Data in Python Request"
#    ]
#   },
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "* Read in data from the Excel spreadsheet (Alarm Survey Data.xlsx) and put into a Pandas DataFrame\n",
#     "* Check the data type of each column\n",
#     "* Convert object columns into numeric or datetime columns, as needed"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": []
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": []
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": []
#   },
#   {
# ...
